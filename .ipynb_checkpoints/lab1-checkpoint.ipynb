# %% [markdown]
# <img src="https://cdn.discordapp.com/attachments/760106198900146176/901843631785250896/vcxvx.png" >

# %% [markdown]
# # 1. СПИСОК БИБЛИОТЕК

# %%
from IPython.display import Image       # Две библиотеки для интеграции картинок и вихуала
from IPython.core.display import HTML 
import numpy as np                      # Массивы (матрицы, векторы, линейная алгебра)
import matplotlib.pyplot as plt         # Научная графика
                                        # Говорим Jupeter Notebook, чтобы весь графический вывод был в браузере, а не в отдельном окне
# %matplotlib inline                     
import pandas as pd                     # Таблицы и временные ряды (dataframe, series)

from sklearn.neighbors import KNeighborsClassifier

import seaborn as sns                   # Еще больше красивой графики для визуализации данных
import sklearn                          # Для расчёта значений метрик и выбора моделей

# %% [markdown]
# # 2. ОСНОВНЫЕ ЗАДАЧИ

# %% [markdown]
# Нашей задачей будет исследовать набор данных, состоящий из фильмов и сериалов, вышедших на Netflix.
# Будет выполнена визуализация данных, вычислены основные характеристики.
# Будет произведена подготовка данных к формированию обучающей и тестовой выборки.
# На основе обучающей и тестовой выборки будет исследовано, как при наличии других признаков можно определить
# значение кассовых сборов, больших или меньших определённого уровня, у фильмов и сериалов.

# %% [markdown]
# # 3. СЧИТАЕМ ДАННЫЕ

# %%
data_raw = pd.read_csv("https://raw.githubusercontent.com/N-Pu/Machine-Learning/master/netflix-rotten-tomatoes-metacritic-imdb.csv")

# %% [markdown]
# # 4. ВЫСЧИТЫВАНИЕ, РЕАЛИЗАЦИЯ И ВИЗУАЛИЗИРОВАНИЕ ОСНОВНЫХ ХАРАКТЕРИСТИК

# %% [markdown]
# Разобьём данные на обучающую и тестовую выборку. Также запустим классификатор ближайших соседей.

# %%
data_raw
# Out:
#                                            Title  \
# 0                               Lets Fight Ghost
# 1                            HOW TO BUILD A GIRL
# 2                                     Centigrade
# 3                                          ANNE+
# 4                                          Moxie
# ...                                          ...
# 15475                     K-POP Extreme Survival
# 15476            DreamWorks Shreks Swamp Stories
# 15477  DreamWorks Happy Holidays from Madagascar
# 15478                DreamWorks Holiday Classics
# 15479   DreamWorks Kung Fu Panda Awesome Secrets
#
#                                         Genre  \
# 0      Crime, Drama, Fantasy, Horror, Romance
# 1                                      Comedy
# 2                             Drama, Thriller
# 3                                       Drama
# 4                     Animation, Short, Drama
# ...                                       ...
# 15475                                     NaN
# 15476                                     NaN
# 15477               Animation, Comedy, Family
# 15478               Animation, Comedy, Family
# 15479       Animation, Action, Comedy, Family
#
#                                                     Tags         Languages  \
# 0      Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1           Dramas,Comedies,Films Based on Books,British           English
# 2                                              Thrillers           English
# 3            TV Dramas,Romantic TV Dramas,Dutch TV Shows           Turkish
# 4      Social Issue Dramas,Teen Movies,Dramas,Comedie...           English
# ...                                                  ...               ...
# 15475  TV Dramas,TV Programmes,TV Comedies,Romantic T...               NaN
# 15476  Animal Tales,Family Comedies,Family Adventures...               NaN
# 15477  TV Comedies,Kids TV,Animal Tales,TV Cartoons,T...           English
# 15478  TV Comedies,Kids TV,TV Cartoons,TV Programmes,...           English
# 15479  TV Comedies,Kids TV,Animal Tales,TV Cartoons,T...           English
#
#       Series or Movie  Hidden Gem Score  \
# 0              Series               4.3
# 1               Movie               7.0
# 2               Movie               6.4
# 3              Series               7.7
# 4               Movie               8.1
# ...               ...               ...
# 15475          Series               NaN
# 15476          Series               NaN
# 15477          Series               8.4
# 15478          Series               8.2
# 15479          Series               8.1
#
#                                     Country Availability       Runtime  \
# 0                                               Thailand  < 30 minutes
# 1                                                 Canada      1-2 hour
# 2                                                 Canada      1-2 hour
# 3                                    Belgium,Netherlands  < 30 minutes
# 4      Lithuania,Poland,France,Iceland,Italy,Spain,Gr...      1-2 hour
# ...                                                  ...           ...
# 15475  South Korea,Argentina,United Kingdom,Australia...  < 30 minutes
# 15476  Russia,Hong Kong,Hungary,Australia,South Korea...  < 30 minutes
# 15477  Belgium,Switzerland,United States,Germany,Unit...  < 30 minutes
# 15478  Belgium,Switzerland,Germany,Argentina,United K...  < 30 minutes
# 15479  Belgium,Switzerland,Germany,United Kingdom,Fra...  < 30 minutes
#
#               Director                      Writer  ... Netflix Release Date  \
# 0      Tomas Alfredson       John Ajvide Lindqvist  ...           2021-03-04
# 1        Coky Giedroyc               Caitlin Moran  ...           2021-03-04
# 2        Brendan Walsh  Brendan Walsh, Daley Nixon  ...           2021-03-04
# 3                  NaN                         NaN  ...           2021-03-04
# 4        Stephen Irwin                         NaN  ...           2021-03-04
# ...                ...                         ...  ...                  ...
# 15475              NaN                         NaN  ...           2015-04-14
# 15476              NaN                         NaN  ...           2015-04-14
# 15477              NaN                         NaN  ...           2015-04-14
# 15478              NaN                         NaN  ...           2015-04-14
# 15479              NaN                         NaN  ...           2015-04-14
#
#                              Production House  \
# 0                   Canal+, Sandrew Metronome
# 1      Film 4, Monumental Pictures, Lionsgate
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 15475                                     NaN
# 15476                                     NaN
# 15477                                     NaN
# 15478                                     Fox
# 15479                                     NaN
#
#                                  Netflix Link  \
# 0      https://www.netflix.com/watch/81415947
# 1      https://www.netflix.com/watch/81041267
# 2      https://www.netflix.com/watch/81305978
# 3      https://www.netflix.com/watch/81336456
# 4      https://www.netflix.com/watch/81078393
# ...                                       ...
# 15475  https://www.netflix.com/watch/80031595
# 15476  https://www.netflix.com/watch/70242630
# 15477  https://www.netflix.com/watch/70259784
# 15478  https://www.netflix.com/watch/70221348
# 15479  https://www.netflix.com/watch/70241791
#
#                                   IMDb Link  \
# 0      https://www.imdb.com/title/tt1139797
# 1      https://www.imdb.com/title/tt4193072
# 2      https://www.imdb.com/title/tt8945942
# 3      https://www.imdb.com/title/tt6132758
# 4      https://www.imdb.com/title/tt2023611
# ...                                     ...
# 15475                                   NaN
# 15476                                   NaN
# 15477                                   NaN
# 15478                                   NaN
# 15479                                   NaN
#
#                                                  Summary  IMDb Votes  \
# 0      A med student with a supernatural gift tries t...    205926.0
# 1      When nerdy Johanna moves to London, things get...      2838.0
# 2      Trapped in a frozen car during a blizzard, a p...      1720.0
# 3      Upon moving into a new place, a 20-something r...      1147.0
# 4      Inspired by her moms rebellious past and a con...        63.0
# ...                                                  ...         ...
# 15475  Seung Yeon decides to chase her dream of becom...         NaN
# 15476  Shrek celebrates Halloween, Puss in Boots is c...         NaN
# 15477  Madagascar goes wild with holiday spirit in th...        71.0
# 15478  Join your DreamWorks friends for these four ho...        82.0
# 15479  In this pair of adventures, Po tells the story...        17.0
#
#                                                    Image  \
# 0      https://occ-0-4708-64.1.nflxso.net/dnm/api/v6/...
# 1      https://occ-0-1081-999.1.nflxso.net/dnm/api/v6...
# 2      https://occ-0-1081-999.1.nflxso.net/dnm/api/v6...
# 3      https://occ-0-1489-1490.1.nflxso.net/dnm/api/v...
# 4      https://occ-0-4039-1500.1.nflxso.net/dnm/api/v...
# ...                                                  ...
# 15475  https://occ-0-2851-38.1.nflxso.net/dnm/api/v6/...
# 15476  https://occ-0-2851-38.1.nflxso.net/dnm/api/v6/...
# 15477  https://occ-0-2773-2774.1.nflxso.net/dnm/api/v...
# 15478  https://occ-0-2851-38.1.nflxso.net/dnm/api/v6/...
# 15479  https://occ-0-2851-38.1.nflxso.net/dnm/api/v6/...
#
#                                                   Poster  \
# 0      https://m.media-amazon.com/images/M/MV5BOWM4NT...
# 1      https://m.media-amazon.com/images/M/MV5BZGUyN2...
# 2      https://m.media-amazon.com/images/M/MV5BODM2MD...
# 3      https://m.media-amazon.com/images/M/MV5BNWRkMz...
# 4      https://m.media-amazon.com/images/M/MV5BODYyNW...
# ...                                                  ...
# 15475                                                NaN
# 15476                                                NaN
# 15477                                                NaN
# 15478                                                NaN
# 15479                                                NaN
#
#                                       TMDb Trailer Trailer Site
# 0                                              NaN          NaN
# 1      https://www.youtube.com/watch?v=eIbcxPy4okQ      YouTube
# 2      https://www.youtube.com/watch?v=0RvV7TNUlkQ      YouTube
# 3                                              NaN          NaN
# 4                                              NaN          NaN
# ...                                            ...          ...
# 15475                                          NaN          NaN
# 15476                                          NaN          NaN
# 15477                                          NaN          NaN
# 15478                                          NaN          NaN
# 15479                                          NaN          NaN
#
# [15480 rows x 29 columns]

# %%
# для начала избавимся от неннужных принаков 
data_raw.drop(['Netflix Link', 'IMDb Link', 'Summary', 'Image', 'Poster','Tags', 'TMDb Trailer', 'Trailer Site'], axis=1, inplace = True)

# %%
data_raw.head(20)
# Out:
#                          Title                                     Genre  \
# 0             Lets Fight Ghost    Crime, Drama, Fantasy, Horror, Romance
# 1          HOW TO BUILD A GIRL                                    Comedy
# 2                   Centigrade                           Drama, Thriller
# 3                        ANNE+                                     Drama
# 4                        Moxie                   Animation, Short, Drama
# 5             The Con-Heartist                           Comedy, Romance
# 6                 Gleboka woda                                     Drama
# 7                     Instynkt                                     Crime
# 8                Only a Mother                                     Drama
# 9                   Snowroller                                    Comedy
# 10                Sunes Summer                   Comedy, Family, Fantasy
# 11               The Invisible  Crime, Drama, Fantasy, Mystery, Thriller
# 12  The Simple Minded Murderer                                     Drama
# 13       The Stig-Helmer Story                             Comedy, Drama
# 14             To Kill a Child                              Short, Drama
# 15                       Joker                    Crime, Drama, Thriller
# 16                           I        Action, Adventure, Fantasy, Sci-Fi
# 17            Harrys Daughters        Adventure, Drama, Fantasy, Mystery
# 18               Gyllene Tider                                     Music
# 19              False As Water                           Drama, Thriller
#
#                               Languages Series or Movie  Hidden Gem Score  \
# 0                      Swedish, Spanish          Series               4.3
# 1                               English           Movie               7.0
# 2                               English           Movie               6.4
# 3                               Turkish          Series               7.7
# 4                               English           Movie               8.1
# 5                                  Thai           Movie               8.6
# 6                                Polish          Series               8.7
# 7                                Polish          Series               6.9
# 8                               Swedish           Movie               8.3
# 9   Swedish, English, German, Norwegian           Movie               5.3
# 10                              Swedish           Movie               7.5
# 11                              English           Movie               2.0
# 12                     Scanian, Swedish           Movie               7.8
# 13                     Swedish, English           Movie               6.4
# 14                              Spanish           Movie               8.8
# 15                              English           Movie               3.5
# 16                    English, Sanskrit           Movie               2.8
# 17                              English           Movie               4.4
# 18                              Swedish           Movie               8.8
# 19                              Swedish           Movie               7.9
#
#                                  Country Availability       Runtime  \
# 0                                            Thailand  < 30 minutes
# 1                                              Canada      1-2 hour
# 2                                              Canada      1-2 hour
# 3                                 Belgium,Netherlands  < 30 minutes
# 4   Lithuania,Poland,France,Iceland,Italy,Spain,Gr...      1-2 hour
# 5                                            Thailand       > 2 hrs
# 6                                              Poland  < 30 minutes
# 7                                              Poland  < 30 minutes
# 8   Lithuania,Poland,France,Italy,Spain,Greece,Bel...      1-2 hour
# 9   Lithuania,Poland,France,Italy,Spain,Greece,Cze...      1-2 hour
# 10  Lithuania,Poland,France,Italy,Spain,Greece,Cze...      1-2 hour
# 11  Lithuania,Poland,France,Italy,Spain,Greece,Cze...      1-2 hour
# 12  Lithuania,Poland,France,Italy,Spain,Greece,Cze...      1-2 hour
# 13  Lithuania,Poland,France,Italy,Spain,Greece,Cze...      1-2 hour
# 14  Lithuania,Poland,France,Italy,Spain,Greece,Cze...  < 30 minutes
# 15  Lithuania,Poland,France,Italy,Spain,Greece,Bel...      1-2 hour
# 16  Lithuania,Poland,France,Italy,Spain,Greece,Cze...      1-2 hour
# 17  Lithuania,Poland,France,Italy,Spain,Greece,Cze...      1-2 hour
# 18  Lithuania,Poland,France,Italy,Spain,Greece,Cze...    30-60 mins
# 19  Lithuania,Poland,France,Italy,Spain,Greece,Cze...      1-2 hour
#
#                                      Director  \
# 0                             Tomas Alfredson
# 1                               Coky Giedroyc
# 2                               Brendan Walsh
# 3                                         NaN
# 4                               Stephen Irwin
# 5                               Mez Tharatorn
# 6                                         NaN
# 7                                         NaN
# 8                                 Alf Sjöberg
# 9                                 Lasse Åberg
# 10                               Jon Holmberg
# 11                             David S. Goyer
# 12                             Hans Alfredson
# 13                                Lasse Åberg
# 14  José Esteban Alenda, César Esteban Alenda
# 15                              Todd Phillips
# 16                               George Lucas
# 17                                David Yates
# 18                            Lasse Hallström
# 19                             Hans Alfredson
#
#                                                Writer  \
# 0                               John Ajvide Lindqvist
# 1                                       Caitlin Moran
# 2                          Brendan Walsh, Daley Nixon
# 3                                                 NaN
# 4                                                 NaN
# 5   Pattaranad Bhiboonsawade, Thodsapon Thiptinnak...
# 6                                                 NaN
# 7                                                 NaN
# 8                                   Ivar Lo-Johansson
# 9                             Lasse Åberg, Bo Jonsson
# 10  Jon Holmberg, Daniella Mendel-Enk, Sara Young,...
# 11              Christine Roum, Mats Wahl, Mick Davis
# 12                                     Hans Alfredson
# 13                                        Lasse Åberg
# 14  José Esteban Alenda, Victoria Ruiz, César Este...
# 15  Scott Silver, Jerry Robinson, Todd Phillips, B...
# 16                                       George Lucas
# 17                         Steve Kloves, J.K. Rowling
# 18                                                NaN
# 19                                     Hans Alfredson
#
#                                                Actors  ... IMDb Score  \
# 0   Kåre Hedebrant, Per Ragnar, Lina Leandersson, ...  ...        7.9
# 1   Paddy Considine, Cleo, Beanie Feldstein, Dónal...  ...        5.8
# 2                   Genesis Rodriguez, Vincent Piazza  ...        4.3
# 3   Vahide Perçin, Gonca Vuslateri, Cansu Dere, Be...  ...        6.5
# 4                                        Ragga Gudrun  ...        6.3
# 5   Thiti Mahayotaruk, Nadech Kugimiya, Kathaleeya...  ...        7.4
# 6   Marcin Dorocinski, Piotr Nowak, Julia Kijowska...  ...        7.5
# 7   Pawel Królikowski, Szymon Bobrowski, Danuta St...  ...        3.9
# 8   Ulf Palme, Ragnar Falck, Hugo Björne, Eva Dahl...  ...        6.7
# 9   Jon Skolmen, Cecilia Walton, Lasse Åberg, Eva ...  ...        6.6
# 10  Elis Gerdt, Tea Stjärne, Fredrik Hallgren, Bax...  ...        5.5
# 11  Marcia Gay Harden, Chris Marquette, Margarita ...  ...        6.2
# 12  Stellan Skarsgård, Hans Alfredson, Per Myrberg...  ...        7.6
# 13  Jon Skolmen, Ida Högberg, Lasse Åberg, Tobias ...  ...        4.5
# 14  Manolo Solo, Roger Príncep, Cristina Marcos, R...  ...        7.7
# 15  Joaquin Phoenix, Zazie Beetz, Robert De Niro, ...  ...        8.4
# 16  Liam Neeson, Ewan McGregor, Natalie Portman, J...  ...        6.5
# 17  Ralph Fiennes, Alan Rickman, Michael Gambon, D...  ...        8.1
# 18  Micke Andersson, Anders Herrlin, Göran Fritzso...  ...        7.7
# 19  Marie Göranzon, Stellan Skarsgård, Sverre Anke...  ...        6.3
#
#     Rotten Tomatoes Score  Metacritic Score  Awards Received  \
# 0                    98.0              82.0             74.0
# 1                    79.0              69.0              1.0
# 2                     NaN              46.0              NaN
# 3                     NaN               NaN              1.0
# 4                     NaN               NaN              NaN
# 5                     NaN               NaN              NaN
# 6                     NaN               NaN              2.0
# 7                     NaN               NaN              NaN
# 8                     NaN               NaN              2.0
# 9                     NaN               NaN              NaN
# 10                    NaN               NaN              NaN
# 11                   20.0              36.0              NaN
# 12                   92.0               NaN              7.0
# 13                    NaN               NaN              NaN
# 14                    NaN               NaN              2.0
# 15                   68.0              59.0            112.0
# 16                   52.0              51.0             26.0
# 17                   96.0              85.0             46.0
# 18                    NaN               NaN              NaN
# 19                    NaN               NaN              3.0
#
#     Awards Nominated For     Boxoffice Release Date Netflix Release Date  \
# 0                   57.0    $2,122,065  12 Dec 2008           2021-03-04
# 1                    NaN       $70,632  08 May 2020           2021-03-04
# 2                    NaN       $16,263  28 Aug 2020           2021-03-04
# 3                    NaN           NaN  01 Oct 2016           2021-03-04
# 4                    4.0           NaN  22 Sep 2011           2021-03-04
# 5                    NaN           NaN  03 Dec 2020           2021-03-03
# 6                    4.0           NaN  14 Jun 2011           2021-03-03
# 7                    NaN           NaN  03 Mar 2011           2021-03-03
# 8                    1.0           NaN  31 Oct 1949           2021-03-03
# 9                    NaN           NaN  04 Oct 1985           2021-03-03
# 10                   7.0           NaN  30 Nov 2018           2021-03-03
# 11                   1.0   $20,578,909  27 Apr 2007           2021-03-03
# 12                   2.0           NaN  01 Sep 1985           2021-03-03
# 13                   1.0           NaN  25 Dec 2011           2021-03-03
# 14                   5.0           NaN  07 Feb 2011           2021-03-03
# 15                 228.0  $335,451,311  04 Oct 2019           2021-03-03
# 16                  69.0  $474,544,677  19 May 1999           2021-03-03
# 17                  94.0  $381,409,310  15 Jul 2011           2021-03-03
# 18                   NaN           NaN          NaN           2021-03-03
# 19                   NaN           NaN  08 Nov 1985           2021-03-03
#
#                                      Production House IMDb Votes
# 0                           Canal+, Sandrew Metronome   205926.0
# 1              Film 4, Monumental Pictures, Lionsgate     2838.0
# 2                                                 NaN     1720.0
# 3                                                 NaN     1147.0
# 4                                                 NaN       63.0
# 5                                                 NaN      131.0
# 6                                                 NaN       47.0
# 7                                                 NaN      107.0
# 8                                                 NaN       88.0
# 9                                                 NaN     5926.0
# 10                                                NaN      560.0
# 11        Touchstone Pictures, Spyglass Entertainment    34738.0
# 12        Svensk Filmindustri, Svenska Filminstitutet     2870.0
# 13                                                NaN     1666.0
# 14                                                NaN       78.0
# 15  Bron Studios, Creative Wealth Media Finance, D...   951938.0
# 16                                     Lucasfilm Ltd.   733336.0
# 17  Heyday Films, Moving Picture Company, Warner B...   766594.0
# 18                                                NaN       19.0
# 19                                                NaN      546.0
#
# [20 rows x 21 columns]

# %%
# уберём запятые и знаки доллара 
data_raw["Boxoffice"] = data_raw["Boxoffice"].apply(lambda v: float(str(v).replace(",", "").replace("$", "")))
data_raw["binary_boxoffice"] = np.where(data_raw["Boxoffice"] >= 500000, 1, 0) # 500000 на 1, меньше 500000 на 0. примерное описание кассового сбора

# %% [markdown]
# # СТАЛО ЛУЧШЕ?

# %% [markdown]
# <img src="https://cdn.discordapp.com/attachments/760106198900146176/901868529312215060/073022d1c61b0ed2.png" >

# %%
data_raw["binary_boxoffice"]
# Out:
# 0        1
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 15475    0
# 15476    0
# 15477    0
# 15478    0
# 15479    0
# Name: binary_boxoffice, Length: 15480, dtype: int32

# %%
data_raw.info() # посмотримпо каким признакам у нас хравнятся данные теперь
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15480 entries, 0 to 15479
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  15480 non-null  object
#  1   Genre                  13770 non-null  object
#  2   Languages              13545 non-null  object
#  3   Series or Movie        15480 non-null  object
#  4   Hidden Gem Score       13379 non-null  float64
#  5   Country Availability   15461 non-null  object
#  6   Runtime                15479 non-null  object
#  7   Director               10772 non-null  object
#  8   Writer                 11150 non-null  object
#  9   Actors                 13555 non-null  object
#  10  View Rating            8456 non-null   object
#  11  IMDb Score             13381 non-null  float64
#  12  Rotten Tomatoes Score  6382 non-null   float64
#  13  Metacritic Score       4336 non-null   float64
#  14  Awards Received        6075 non-null   float64
#  15  Awards Nominated For   7661 non-null   float64
#  16  Boxoffice              4007 non-null   float64
#  17  Release Date           13373 non-null  object
#  18  Netflix Release Date   15480 non-null  object
#  19  Production House       5149 non-null   object
#  20  IMDb Votes             13379 non-null  float64
#  21  binary_boxoffice       15480 non-null  int32
# dtypes: float64(8), int32(1), object(13)
# memory usage: 2.5+ MB

# %% [markdown]
# # Опишем признаки сами признаки:

# %% [raw]
# Title - сам фильм/сериал
# Genre - Жанр
# Tags - Частые теги по жанрам
# Languages - Языки
# Series or Movie - Сериалы или фильмы
# Hidden Gem Score - Низкое количество отзывов и высокий рейтинг
# Country Availability - Доступность в стране
# Runtime - Длительность по времени фильма или серии
# Director - Режисёр
# Writer - Сценарист
# Actors - Актеры, появляющиеся в фильмах или сериалах
# View Rating - Система оценки фильмов Ассоциации кинематографистов
# IMDb Score - Оценка от IMDb
# Rotten Tomatoes Score - Оценка от Rotten Tomatoes
# Metacritic Score - Оценка от Metacritic
# Awards Received - Количество полученных наград (Оскар, Золотой глобус и др.)
# Awards Nominated For - Номинация в получении награды (Оскара, Золотого глобуса и др.)
# Boxoffice - Кассовые сборы
# Release Date - Дата выхода фильма или сериала
# Netflix Release Date - Дата выхода фильма или сериала на Нетфликс
# Production House - Кампании производители фильмов или сериалов
# IMDb Votes - Голоса от IMDb
# binary_boxoffice - бинарные кассовые сборы (1, если сборы больше >= 500000, и 0, если <, тобишь не лучшие продажи)

# %%
# Построим все возможные диаграммы рассеивания для каждой пары переменных:
random_subset = np.random.choice(np.arange(data_raw.shape[0]), size=500, replace=False)
# binary_boxoffice = 1, когда сборы >= 500000, и 0, если сборы < 500000
sns.pairplot(data_raw.iloc[random_subset], hue='binary_boxoffice', diag_kind='hist')
plt.legend()
pass
# Out:
# No handles with labels found to put in legend.

# %%
Можно сделать вывод, что очевидной корреляции между параметрами нет.

# %%
# Преобразуем некоторые типы в котегориальтные
data_raw['Genre'] = data_raw['Genre'].astype('category')
data_raw['Runtime'] = data_raw['Runtime'].astype('category')
data_raw['Genre'].dtype
# Out:
# CategoricalDtype(categories=['Movie', 'Series'], ordered=False)

# %%
data_raw['Runtime'].dtype
# Out:
# CategoricalDtype(categories=['1-2 hour', '30-60 mins', '< 30 minutes', '> 2 hrs'], ordered=False)

# %%
#Сгененерируем статистику для обобщения центральной тенденции
data_raw.describe()
# Out:
#        Hidden Gem Score    IMDb Score  Rotten Tomatoes Score  \
# count      13379.000000  13381.000000            6382.000000
# mean           5.937551      6.496054              59.523034
# std            2.250202      1.146910              26.999173
# min            0.600000      1.000000               0.000000
# 25%            3.800000      5.800000              38.000000
# 50%            6.800000      6.600000              64.000000
# 75%            7.900000      7.300000              83.000000
# max            9.800000      9.700000             100.000000
#
#        Metacritic Score  Awards Received  Awards Nominated For     Boxoffice  \
# count       4336.000000      6075.000000           7661.000000  4.007000e+03
# mean          56.813653         8.764444             13.983161  4.568229e+07
# std           17.582545        18.311171             29.821052  7.097634e+07
# min            5.000000         1.000000              1.000000  7.200000e+01
# 25%           44.000000         1.000000              2.000000  7.816345e+05
# 50%           57.000000         3.000000              5.000000  1.955107e+07
# 75%           70.000000         8.000000             12.000000  5.969536e+07
# max          100.000000       300.000000            386.000000  6.593639e+08
#
#          IMDb Votes  binary_boxoffice
# count  1.337900e+04      15480.000000
# mean   4.272841e+04          0.202972
# std    1.257012e+05          0.402225
# min    5.000000e+00          0.000000
# 25%    4.035000e+02          0.000000
# 50%    2.322000e+03          0.000000
# 75%    2.089050e+04          0.000000
# max    2.354197e+06          1.000000

# %%
# И сделаем корреляционную матрицу
cmatrix = data_raw.corr()
cmatrix
# Out:
#                        Hidden Gem Score  IMDb Score  Rotten Tomatoes Score  \
# Hidden Gem Score               1.000000    0.120373               0.397905
# IMDb Score                     0.120373    1.000000               0.710922
# Rotten Tomatoes Score          0.397905    0.710922               1.000000
# Metacritic Score               0.521470    0.717715               0.903345
# Awards Received               -0.112787    0.291142               0.301380
# Awards Nominated For          -0.159500    0.289843               0.309572
# Boxoffice                     -0.211815    0.138257               0.053706
# IMDb Votes                    -0.359540    0.229760               0.181762
# binary_boxoffice              -0.667165    0.047625              -0.037664
#
#                        Metacritic Score  Awards Received  \
# Hidden Gem Score               0.521470        -0.112787
# IMDb Score                     0.717715         0.291142
# Rotten Tomatoes Score          0.903345         0.301380
# Metacritic Score               1.000000         0.431420
# Awards Received                0.431420         1.000000
# Awards Nominated For           0.449726         0.817262
# Boxoffice                      0.061548         0.193976
# IMDb Votes                     0.261384         0.469818
# binary_boxoffice              -0.033004         0.196309
#
#                        Awards Nominated For  Boxoffice  IMDb Votes  \
# Hidden Gem Score                  -0.159500  -0.211815   -0.359540
# IMDb Score                         0.289843   0.138257    0.229760
# Rotten Tomatoes Score              0.309572   0.053706    0.181762
# Metacritic Score                   0.449726   0.061548    0.261384
# Awards Received                    0.817262   0.193976    0.469818
# Awards Nominated For               1.000000   0.284885    0.497690
# Boxoffice                          0.284885   1.000000    0.630301
# IMDb Votes                         0.497690   0.630301    1.000000
# binary_boxoffice                   0.222912   0.336826    0.490041
#
#                        binary_boxoffice
# Hidden Gem Score              -0.667165
# IMDb Score                     0.047625
# Rotten Tomatoes Score         -0.037664
# Metacritic Score              -0.033004
# Awards Received                0.196309
# Awards Nominated For           0.222912
# Boxoffice                      0.336826
# IMDb Votes                     0.490041
# binary_boxoffice               1.000000

# %%
ax = sns.heatmap(data_raw.corr(), annot=True)

# %% [markdown]
# Здесь можно увидеть особох корреляций между оценками разных платформ не удалось, как и собственно ожидалось.

# %% [markdown]
# #  5. ОБРАБОТКА ПРОПУЩЕННЫХ ЗНАЧЕНИЙ

# %% [markdown]
# Найдем столбцы, в которых имеются пропущенные значения и количество таких значений:

# %% [markdown]
# Заполним пропущенные значения медианой.

# %%
data_raw.fillna(data_raw.median(axis = 0), axis=0 , inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_4348/3749499989.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data_raw.fillna(data_raw.median(axis = 0), axis=0 , inplace=True)

# %%
data_raw.isna().sum()
# Out:
# Title                        0
# Genre                     1710
# Languages                 1935
# Series or Movie              0
# Hidden Gem Score             0
# Country Availability        19
# Runtime                      1
# Director                  4708
# Writer                    4330
# Actors                    1925
# View Rating               7024
# IMDb Score                   0
# Rotten Tomatoes Score        0
# Metacritic Score             0
# Awards Received              0
# Awards Nominated For         0
# Boxoffice                    0
# Release Date              2107
# Netflix Release Date         0
# Production House         10331
# IMDb Votes                   0
# binary_boxoffice             0
# dtype: int64

# %%
# Пропущенные значения в столбцах, соответствующих категориальным признакам, заполним модой:
data_raw['Genre'].fillna(data_raw['Genre'].mode().iloc[0], inplace=True)
data_raw['Languages'].fillna(data_raw['Languages'].mode().iloc[0], inplace=True)
data_raw['Country Availability'].fillna(data_raw['Country Availability'].mode().iloc[0], inplace=True)
data_raw['Runtime'].fillna(data_raw['Runtime'].mode().iloc[0], inplace=True)
data_raw['Director'].fillna(data_raw['Director'].mode().iloc[0], inplace=True)
data_raw['Writer'].fillna(data_raw['Writer'].mode().iloc[0], inplace=True)
data_raw['Actors'].fillna(data_raw['Actors'].mode().iloc[0], inplace=True)
data_raw['View Rating'].fillna(data_raw['View Rating'].mode().iloc[0], inplace=True)
data_raw['Release Date'].fillna(data_raw['Release Date'].mode().iloc[0], inplace=True)
data_raw['Production House'].fillna(data_raw['Production House'].mode().iloc[0], inplace=True)

# %%
data_raw.isna() # функция замены Nan на true остальное на false
# Out:
#        Title  Genre  Languages  Series or Movie  Hidden Gem Score  \
# 0      False  False      False            False             False
# 1      False  False      False            False             False
# 2      False  False      False            False             False
# 3      False  False      False            False             False
# 4      False  False      False            False             False
# ...      ...    ...        ...              ...               ...
# 15475  False  False      False            False             False
# 15476  False  False      False            False             False
# 15477  False  False      False            False             False
# 15478  False  False      False            False             False
# 15479  False  False      False            False             False
#
#        Country Availability  Runtime  Director  Writer  Actors  ...  \
# 0                     False    False     False   False   False  ...
# 1                     False    False     False   False   False  ...
# 2                     False    False     False   False   False  ...
# 3                     False    False     False   False   False  ...
# 4                     False    False     False   False   False  ...
# ...                     ...      ...       ...     ...     ...  ...
# 15475                 False    False     False   False   False  ...
# 15476                 False    False     False   False   False  ...
# 15477                 False    False     False   False   False  ...
# 15478                 False    False     False   False   False  ...
# 15479                 False    False     False   False   False  ...
#
#        Rotten Tomatoes Score  Metacritic Score  Awards Received  \
# 0                      False             False            False
# 1                      False             False            False
# 2                      False             False            False
# 3                      False             False            False
# 4                      False             False            False
# ...                      ...               ...              ...
# 15475                  False             False            False
# 15476                  False             False            False
# 15477                  False             False            False
# 15478                  False             False            False
# 15479                  False             False            False
#
#        Awards Nominated For  Boxoffice  Release Date  Netflix Release Date  \
# 0                     False      False         False                 False
# 1                     False      False         False                 False
# 2                     False      False         False                 False
# 3                     False      False         False                 False
# 4                     False      False         False                 False
# ...                     ...        ...           ...                   ...
# 15475                 False      False         False                 False
# 15476                 False      False         False                 False
# 15477                 False      False         False                 False
# 15478                 False      False         False                 False
# 15479                 False      False         False                 False
#
#        Production House  IMDb Votes  binary_boxoffice
# 0                 False       False             False
# 1                 False       False             False
# 2                 False       False             False
# 3                 False       False             False
# 4                 False       False             False
# ...                 ...         ...               ...
# 15475             False       False             False
# 15476             False       False             False
# 15477             False       False             False
# 15478             False       False             False
# 15479             False       False             False
#
# [15480 rows x 22 columns]

# %%
data_raw.head(10)
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2           Centigrade                         Drama, Thriller
# 3                ANNE+                                   Drama
# 4                Moxie                 Animation, Short, Drama
# 5     The Con-Heartist                         Comedy, Romance
# 6         Gleboka woda                                   Drama
# 7             Instynkt                                   Crime
# 8        Only a Mother                                   Drama
# 9           Snowroller                                  Comedy
#
#                              Languages Series or Movie  Hidden Gem Score  \
# 0                     Swedish, Spanish          Series               4.3
# 1                              English           Movie               7.0
# 2                              English           Movie               6.4
# 3                              Turkish          Series               7.7
# 4                              English           Movie               8.1
# 5                                 Thai           Movie               8.6
# 6                               Polish          Series               8.7
# 7                               Polish          Series               6.9
# 8                              Swedish           Movie               8.3
# 9  Swedish, English, German, Norwegian           Movie               5.3
#
#                                 Country Availability       Runtime  \
# 0                                           Thailand  < 30 minutes
# 1                                             Canada      1-2 hour
# 2                                             Canada      1-2 hour
# 3                                Belgium,Netherlands  < 30 minutes
# 4  Lithuania,Poland,France,Iceland,Italy,Spain,Gr...      1-2 hour
# 5                                           Thailand       > 2 hrs
# 6                                             Poland  < 30 minutes
# 7                                             Poland  < 30 minutes
# 8  Lithuania,Poland,France,Italy,Spain,Greece,Bel...      1-2 hour
# 9  Lithuania,Poland,France,Italy,Spain,Greece,Cze...      1-2 hour
#
#            Director                                             Writer  \
# 0   Tomas Alfredson                              John Ajvide Lindqvist
# 1     Coky Giedroyc                                      Caitlin Moran
# 2     Brendan Walsh                         Brendan Walsh, Daley Nixon
# 3  Steven Spielberg                                    Fujio F. Fujiko
# 4     Stephen Irwin                                    Fujio F. Fujiko
# 5     Mez Tharatorn  Pattaranad Bhiboonsawade, Thodsapon Thiptinnak...
# 6  Steven Spielberg                                    Fujio F. Fujiko
# 7  Steven Spielberg                                    Fujio F. Fujiko
# 8       Alf Sjöberg                                  Ivar Lo-Johansson
# 9       Lasse Åberg                            Lasse Åberg, Bo Jonsson
#
#                                               Actors  ...  \
# 0  Kåre Hedebrant, Per Ragnar, Lina Leandersson, ...  ...
# 1  Paddy Considine, Cleo, Beanie Feldstein, Dónal...  ...
# 2                  Genesis Rodriguez, Vincent Piazza  ...
# 3  Vahide Perçin, Gonca Vuslateri, Cansu Dere, Be...  ...
# 4                                       Ragga Gudrun  ...
# 5  Thiti Mahayotaruk, Nadech Kugimiya, Kathaleeya...  ...
# 6  Marcin Dorocinski, Piotr Nowak, Julia Kijowska...  ...
# 7  Pawel Królikowski, Szymon Bobrowski, Danuta St...  ...
# 8  Ulf Palme, Ragnar Falck, Hugo Björne, Eva Dahl...  ...
# 9  Jon Skolmen, Cecilia Walton, Lasse Åberg, Eva ...  ...
#
#   Rotten Tomatoes Score  Metacritic Score  Awards Received  \
# 0                  98.0              82.0             74.0
# 1                  79.0              69.0              1.0
# 2                  64.0              46.0              3.0
# 3                  64.0              57.0              1.0
# 4                  64.0              57.0              3.0
# 5                  64.0              57.0              3.0
# 6                  64.0              57.0              2.0
# 7                  64.0              57.0              3.0
# 8                  64.0              57.0              2.0
# 9                  64.0              57.0              3.0
#
#    Awards Nominated For   Boxoffice  Release Date  Netflix Release Date  \
# 0                  57.0   2122065.0   12 Dec 2008            2021-03-04
# 1                   5.0     70632.0   08 May 2020            2021-03-04
# 2                   5.0     16263.0   28 Aug 2020            2021-03-04
# 3                   5.0  19551067.0   01 Oct 2016            2021-03-04
# 4                   4.0  19551067.0   22 Sep 2011            2021-03-04
# 5                   5.0  19551067.0   03 Dec 2020            2021-03-03
# 6                   4.0  19551067.0   14 Jun 2011            2021-03-03
# 7                   5.0  19551067.0   03 Mar 2011            2021-03-03
# 8                   1.0  19551067.0   31 Oct 1949            2021-03-03
# 9                   5.0  19551067.0   04 Oct 1985            2021-03-03
#
#                          Production House IMDb Votes binary_boxoffice
# 0               Canal+, Sandrew Metronome   205926.0                1
# 1  Film 4, Monumental Pictures, Lionsgate     2838.0                0
# 2                                 Netflix     1720.0                0
# 3                                 Netflix     1147.0                0
# 4                                 Netflix       63.0                0
# 5                                 Netflix      131.0                0
# 6                                 Netflix       47.0                0
# 7                                 Netflix      107.0                0
# 8                                 Netflix       88.0                0
# 9                                 Netflix     5926.0                0
#
# [10 rows x 22 columns]

# %%
data_raw.describe()
data_new.head()
# Out:
#                  Title  Series or Movie  Hidden Gem Score  IMDb Score  \
# 0     Lets Fight Ghost                0               4.3         7.9
# 1  HOW TO BUILD A GIRL                1               7.0         5.8
# 2           Centigrade                1               6.4         4.3
# 3                ANNE+                0               7.7         6.5
# 4                Moxie                1               8.1         6.3
#
#    Rotten Tomatoes Score  Metacritic Score  Awards Received  \
# 0                   98.0              82.0             74.0
# 1                   79.0              69.0              1.0
# 2                    NaN              46.0              NaN
# 3                    NaN               NaN              1.0
# 4                    NaN               NaN              NaN
#
#    Awards Nominated For  Boxoffice  binary_boxoffice  1-2 hour  30-60 mins  \
# 0                  57.0  2122065.0                 1         0           0
# 1                   NaN    70632.0                 0         1           0
# 2                   NaN    16263.0                 0         1           0
# 3                   NaN        NaN                 0         0           0
# 4                   4.0        NaN                 0         1           0
#
#    < 30 minutes  > 2 hrs
# 0             1        0
# 1             0        0
# 2             0        0
# 3             1        0
# 4             0        0

# %% [markdown]
# # 6. Обрабатываем номинальные признаки

# %% [markdown]
# Алгоритмы из библиотеки scikit-learn (почти) не умеют работать напрямую с категориальными признаками. Поэтому их вначале надо закодировать с помощью числовых принаков.

# %%
# Отберём подтаблицу с самыми нужными признаками и далее будем работать с ней
data_new = data_raw.loc[:, ['Title', 'Series or Movie', 'Hidden Gem Score', 'Runtime', 'IMDb Score',
                            'Rotten Tomatoes Score', 'Metacritic Score', 'Awards Received', 'Awards Nominated For',
                           'Boxoffice','binary_boxoffice']].copy()
data_new.head()
# Out:
#                  Title Series or Movie  Hidden Gem Score       Runtime  \
# 0     Lets Fight Ghost          Series               4.3  < 30 minutes
# 1  HOW TO BUILD A GIRL           Movie               7.0      1-2 hour
# 2           Centigrade           Movie               6.4      1-2 hour
# 3                ANNE+          Series               7.7  < 30 minutes
# 4                Moxie           Movie               8.1      1-2 hour
#
#    IMDb Score  Rotten Tomatoes Score  Metacritic Score  Awards Received  \
# 0         7.9                   98.0              82.0             74.0
# 1         5.8                   79.0              69.0              1.0
# 2         4.3                   64.0              46.0              3.0
# 3         6.5                   64.0              57.0              1.0
# 4         6.3                   64.0              57.0              3.0
#
#    Awards Nominated For   Boxoffice  binary_boxoffice
# 0                  57.0   2122065.0                 1
# 1                   5.0     70632.0                 0
# 2                   5.0     16263.0                 0
# 3                   5.0  19551067.0                 0
# 4                   4.0  19551067.0                 0

# %%
# Бинарный признак 'Series or Movie' заменим на числовой.
data_new['Series or Movie'] = pd.factorize(data_new['Series or Movie'])[0] # 0 - series, 1 - movie

# %%
Runtime_dummies = pd.get_dummies(data_new['Runtime'])

# %%
data_new = pd.concat((data_new, Runtime_dummies), axis=1)
data_new = data_new.drop(['Runtime'], axis=1)

# %%
data_new.head()
# Out:
#                  Title  Series or Movie  Hidden Gem Score  IMDb Score  \
# 0     Lets Fight Ghost                0               4.3         7.9
# 1  HOW TO BUILD A GIRL                1               7.0         5.8
# 2           Centigrade                1               6.4         4.3
# 3                ANNE+                0               7.7         6.5
# 4                Moxie                1               8.1         6.3
#
#    Rotten Tomatoes Score  Metacritic Score  Awards Received  \
# 0                   98.0              82.0             74.0
# 1                   79.0              69.0              1.0
# 2                   64.0              46.0              3.0
# 3                   64.0              57.0              1.0
# 4                   64.0              57.0              3.0
#
#    Awards Nominated For   Boxoffice  binary_boxoffice  1-2 hour  30-60 mins  \
# 0                  57.0   2122065.0                 1         0           0
# 1                   5.0     70632.0                 0         1           0
# 2                   5.0     16263.0                 0         1           0
# 3                   5.0  19551067.0                 0         0           0
# 4                   4.0  19551067.0                 0         1           0
#
#    < 30 minutes  > 2 hrs
# 0             1        0
# 1             0        0
# 2             0        0
# 3             1        0
# 4             0        0

# %% [markdown]
# # 7. НОРМАЛИЗАЦИЯ ПРИЗНАКОВ

# %% [markdown]
# Думаю, что перед началом применения алгоритмов машинного обучения, наверно, стоит сделать ленейное преобразование. Оно должно помочь, наверно.

# %% [markdown]
# <img src="https://cdn.discordapp.com/attachments/760106198900146176/902262346326609940/photoshop_iYsE3Jopez.png">

# %%
data_stand = (data_new - data_new.mean(axis = 0))/data_new.std(axis = 0)
data_stand.describe()
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_4348/2453001301.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data_stand = (data_new - data_new.mean(axis = 0))/data_new.std(axis = 0)
#            1-2 hour    30-60 mins  < 30 minutes       > 2 hrs  \
# count  1.548000e+04  1.548000e+04  1.548000e+04  1.548000e+04
# mean   1.138337e-16 -5.508083e-18 -1.468822e-17  3.672055e-17
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.197763e+00 -1.484945e-01 -5.898643e-01 -3.882635e-01
# 25%   -1.197763e+00 -1.484945e-01 -5.898643e-01 -3.882635e-01
# 50%    8.348361e-01 -1.484945e-01 -5.898643e-01 -3.882635e-01
# 75%    8.348361e-01 -1.484945e-01  1.695196e+00 -3.882635e-01
# max    8.348361e-01  6.733823e+00  1.695196e+00  2.575404e+00
#
#        Awards Nominated For  Awards Received     Boxoffice  Hidden Gem Score  \
# count          15480.000000     1.548000e+04  15480.000000      1.548000e+04
# mean               0.000000    -2.203233e-17      0.000000      2.056351e-16
# std                1.000000     1.000000e+00      1.000000      1.000000e+00
# min               -0.393676    -3.608732e-01     -0.694728     -2.581848e+00
# 25%               -0.207226    -1.915370e-01     -0.178574     -9.725138e-01
# 50%               -0.207226    -1.915370e-01     -0.178574      3.528200e-01
# 75%               -0.207226    -1.915370e-01     -0.178574      8.261534e-01
# max               17.552094     2.495489e+01     16.712724      1.772820e+00
#
#          IMDb Score  Metacritic Score  Rotten Tomatoes Score  Series or Movie  \
# count  1.548000e+04      1.548000e+04           1.548000e+04     1.548000e+04
# mean  -9.547344e-17     -2.093072e-16          -1.982910e-16     4.957275e-17
# std    1.000000e+00      1.000000e+00           1.000000e+00     1.000000e+00
# min   -5.164589e+00     -5.582706e+00          -3.556853e+00    -1.758349e+00
# 25%   -4.781555e-01      5.609421e-03           1.056245e-01     5.686786e-01
# 50%    8.421655e-02      5.609421e-03           1.056245e-01     5.686786e-01
# 75%    6.465886e-01      5.609421e-03           1.056245e-01     5.686786e-01
# max    2.989806e+00      4.626717e+00           2.165768e+00     5.686786e-01
#
#        binary_boxoffice
# count      15480.000000
# mean           0.000000
# std            1.000000
# min           -0.504623
# 25%           -0.504623
# 50%           -0.504623
# 75%           -0.504623
# max            1.981551

# %% [markdown]
# # 8. ОБУЧАЮЩАЯ И ТЕСТОВЫЕ ВЫБОРКИ

# %%
data_stand.columns
# Out:
# Index(['1-2 hour', '30-60 mins', '< 30 minutes', '> 2 hrs',
#        'Awards Nominated For', 'Awards Received', 'Boxoffice',
#        'Hidden Gem Score', 'IMDb Score', 'Metacritic Score',
#        'Rotten Tomatoes Score', 'Series or Movie', 'Title',
#        'binary_boxoffice'],
#       dtype='object')

# %%
X = data_stand.drop(['IMDb Score', 'Title', 'Boxoffice','Awards Received','Metacritic Score','Rotten Tomatoes Score', 'Awards Nominated For', 'binary_boxoffice'], axis=1)
y = data_new['binary_boxoffice']

# %%
X.head()
# Out:
#    1-2 hour  30-60 mins  < 30 minutes   > 2 hrs  Hidden Gem Score  \
# 0 -1.197763   -0.148494      1.695196 -0.388263         -0.830514
# 1  0.834836   -0.148494     -0.589864 -0.388263          0.447487
# 2  0.834836   -0.148494     -0.589864 -0.388263          0.163487
# 3 -1.197763   -0.148494      1.695196 -0.388263          0.778820
# 4  0.834836   -0.148494     -0.589864 -0.388263          0.968153
#
#    Series or Movie
# 0        -1.758349
# 1         0.568679
# 2         0.568679
# 3        -1.758349
# 4         0.568679

# %%
N_train, _ = X_train.shape 
N_test,  _ = X_test.shape

# %%
N_train, N_test
# Out:
# (11610, 3870)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %% [markdown]
# # 9. kNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_default = KNeighborsClassifier()
knn_default.fit(X_train, y_train)
knn_training_predict = 50 * knn_default.score(X_train, y_train)
knn_test_predict = 50 * knn_default.score(X_test, y_test)
print("Accuracy) Train : {:.2f}%, Test: {:.2f}%. ".format(knn_training_predict, knn_test_predict))

err_train = np.mean(y_train != knn_default.predict(X_train))
err_test  = np.mean(y_test  != knn_default.predict(X_test))
print("Error) Train : {:.8f}, Test: {:.8f} ".format(err_train, err_test))
# Out:
# e:\p\try1\venv\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# e:\p\try1\venv\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# Accuracy) Train : 44.34%, Test: 44.37%.
# e:\p\try1\venv\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# e:\p\try1\venv\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# Error) Train : 0.11317829, Test: 0.11266150

# %%
knn_2 = KNeighborsClassifier(n_neighbors = 12)
knn_2.fit(X_train, y_train)
knn_training_predict = 100 * knn_2.score(X_train, y_train)
knn_test_predict = 100 * knn_2.score(X_test, y_test)
print("Accuracy) Train : {:.2f}%, Test: {:.2f}%. ".format(knn_training_predict, knn_test_predict))

err_train = np.mean(y_train != knn_2.predict(X_train))
err_test  = np.mean(y_test  != knn_2.predict(X_test))
print("Error) Train : {:.8f}, Test: {:.8f} ".format(err_train, err_test))
# Out:
# e:\p\try1\venv\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# e:\p\try1\venv\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# Accuracy) Train : 89.10%, Test: 89.56%.
# e:\p\try1\venv\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# e:\p\try1\venv\lib\site-packages\sklearn\base.py:441: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# Error) Train : 0.10895780, Test: 0.10439276

# %% [markdown]
# # ВЫВОД

# %% [markdown]
# При малом колличестве соседей точность выше. При этом на тестовой выборке  точность снизилась. При увеличении соседей точность на обучающей выборке ухудшается но алгоритм лучше натренируется.
